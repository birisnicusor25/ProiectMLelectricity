# %% [markdown]
# Analiza exploratorie a setului de date Electricity

# %%
import pandas as pd
import matplotlib.pyplot as plt
``

# %%
df = pd.read_csv('data/electricity.csv')
df.head()
``

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()
``

# %%
df['class'].value_counts().plot(kind='bar')
plt.title('Distributia clasei')
plt.show()

# %%
df['nswprice'].hist(bins=30)
plt.title('NSW price')

# %% [markdown]
# Curatarea datelor
#
# Setul de date nu contine valori lipsa si este deja normalizat,
# deci nu a fost nevoie de curatare suplimentara.
